# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://en.wikipedia.org/wiki/Demographics_of_Turkey'

page = requests.get(url)

soup = BeautifulSoup(page.text, 'html')

# %%
soup.find('table', class_ = 'wikitable sortable')
# Out:
# <table class="wikitable sortable" style="text-align:right">
# <tbody><tr>
# <th>
# </th>
# <th style="width:80pt;">Population (31.12.)
# </th>
# <th style="width:80pt;">Live births
# </th>
# <th style="width:80pt;">Deaths
# </th>
# <th style="width:80pt;">Natural change
# </th>
# <th style="width:80pt;">Crude birth rate (per 1000)
# </th>
# <th style="width:80pt;">Crude death (per 1000)
# </th>
# <th style="width:80pt;">Natural increase (per 1000)
# </th>
# <th style="width:80pt;">Total fertility rate (TFR)
# </th></tr>
# <tr>
# <td>1990
# </td>
# <td style="text-align:right;">
# </td>
# <td style="text-align:right;">1,392,000
# </td>
# <td style="text-align:right;">388,000
# </td>
# <td style="text-align:right;">1,004,000
# </td>
# <td style="text-align:right;">
# </td>
# <td style="text-align:right;">
# </td>
# <td style="text-align:right;">
# </td>
# <td style="text-align:right; color:blue;">3.11
# </td></tr>
# <tr>
# <td>1991
# </td>
# <td style="text-align:right;">
# </td>
# ...

# %%
table = soup.find('table', class_ = 'wikitable sortable')

# %%
table.find_all('th')
# Out:
# [<th>
#  </th>,
#  <th style="width:80pt;">Population (31.12.)
#  </th>,
#  <th style="width:80pt;">Live births
#  </th>,
#  <th style="width:80pt;">Deaths
#  </th>,
#  <th style="width:80pt;">Natural change
#  </th>,
#  <th style="width:80pt;">Crude birth rate (per 1000)
#  </th>,
#  <th style="width:80pt;">Crude death (per 1000)
#  </th>,
#  <th style="width:80pt;">Natural increase (per 1000)
#  </th>,
#  <th style="width:80pt;">Total fertility rate (TFR)
#  </th>]

# %%
table_titles = table.find_all('th')
word_table_titles = [title.text.strip() for title in table_titles]

# %%
print(word_table_titles)
# Out:
# ['', 'Population (31.12.)', 'Live births', 'Deaths', 'Natural change', 'Crude birth rate (per 1000)', 'Crude death (per 1000)', 'Natural increase (per 1000)', 'Total fertility rate (TFR)']

# %%
word_table_titles = ['Year', 'Population (31.12.)', 'Live births', 'Deaths', 'Natural change', 'Crude birth rate (per 1000)', 'Crude death (per 1000)', 'Natural increase (per 1000)', 'Total fertility rate (TFR)']

# %%
import pandas as pd

# %%
df = pd.DataFrame(columns=word_table_titles)

# %%
df
# Out:
# Empty DataFrame
# Columns: [Year, Population (31.12.), Live births, Deaths, Natural change, Crude birth rate (per 1000), Crude death (per 1000), Natural increase (per 1000), Total fertility rate (TFR)]
# Index: []

# %%
column_data = table.find_all('tr')

# %%
for row in column_data[1:]:
    row_data = row.find_all('td')
    individual_row_data = [data.text.strip() for data in row_data]
    
    lenght = len(df)
    df.loc[lenght] = individual_row_data

# %%
df
# Out:
#     Year Population (31.12.)  Live births   Deaths Natural change  \
# 0   1990                        1,392,000  388,000      1,004,000
# 1   1991                        1,390,000  391,000        999,000
# 2   1992                        1,388,000  394,000        994,000
# 3   1993                        1,385,000  396,000        989,000
# 4   1994                        1,372,000  399,000        973,000
# 5   1995                        1,368,000  402,000        966,000
# 6   1996                        1,386,000  419,000        967,000
# 7   1997                        1,317,000  424,000        893,000
# 8   1998                        1,318,000  426,000        892,000
# 9   1999                        1,313,000  427,000        886,000
# 10  2000                        1,307,000  422,000        885,000
# 11  2001                        1,323,341  175,137      1,148,204
# 12  2002                        1,229,555  175,434      1,054,121
# ...

# %%
df.to_csv(r'C:\Users\Raupeling\Desktop\csvFromPyhton\Demographics_of_Turkey.csv', index = False)
